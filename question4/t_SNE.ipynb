# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Suppose `hidden_activations` contains the 20-neuron outputs for all test images (shape: [num_samples, 20])
# `labels` contains the true digit labels (shape: [num_samples])

tsne = TSNE(n_components=2, random_state=42)  # Project to 2D for visualization
embeddings_2d = tsne.fit_transform(hidden_activations)

# Plot (each color = digit class)
plt.figure(figsize=(8,6))
for digit in range(10):
    idx = labels == digit
    plt.scatter(embeddings_2d[idx, 0], embeddings_2d[idx, 1], label=f"{digit}", alpha=0.7, s=15)
plt.legend()
plt.title("t-SNE of 20-neuron layer (after training)")
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       4 # Suppose `hidden_activations` contains the 20-neuron outputs for all test images (shape: [num_samples, 20])
#       5 # `labels` contains the true digit labels (shape: [num_samples])
#       7 tsne = TSNE(n_components=2, random_state=42)  # Project to 2D for visualization
# ----> 8 embeddings_2d = tsne.fit_transform(hidden_activations)
#      10 # Plot (each color = digit class)
#      11 plt.figure(figsize=(8,6))
#
# NameError: name 'hidden_activations' is not defined
